# %%
import torch

from loader.Toy_dataset import Toy, toy_visualizer
from loader.Pouring_dataset import Pouring

from vis_utils.planar_spline_utils import (
	plot_2d_wall,
	plot_init_point,
	plot_traj,
	scatter_traj
)
import matplotlib.pyplot as plt

import open3d as o3d
import open3d.visualization.gui as gui
import open3d.visualization.rendering as rendering
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
ds1 = Toy('datasets/EXP1/')
ds2 = Toy('datasets/EXP2/')
ds3 = Toy('datasets/EXP3/')

fig, axs = plt.subplots(1, 3, figsize=(12, 3))
toy_visualizer(ds1.env, axs[0], traj=ds1.data, label=ds1.targets)
toy_visualizer(ds2.env, axs[1], traj=ds2.data, label=ds2.targets)
toy_visualizer(ds3.env, axs[2], traj=ds3.data, label=ds3.targets)
# Out:
# Toy split training | torch.Size([10, 201, 2])
# Toy split training | torch.Size([15, 201, 2])
# Toy split training | torch.Size([20, 201, 2])

# %%
ds = Pouring()
print(ds.traj_data_.size())
print(ds.labels_.size())
# Out:
# Pouring dataset is ready; # of trajectories: 10
# torch.Size([10, 480, 4, 4])
# torch.Size([10, 3])

# %%
# !python "1.1. visualize_pouring_dataset.py"
# Out:
# The name of the file is "1_water_200.pkl"
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D WARNING] Geometry frame_init has already been added to scene graph.
# [Open3D WARNING] Geometry box_init has already been added to scene graph.
# The name of the file is "2_water_200.pkl"
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D WARNING] Geometry frame_init has already been added to scene graph.
# [Open3D WARNING] Geometry box_init has already been added to scene graph.
# The name of the file is "3_water_200.pkl"
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D INFO] Skipping non-triangle primitive geometry of type: 2
# [Open3D WARNING] Geometry frame_init has already been added to scene graph.
# [Open3D WARNING] Geometry box_init has already been added to scene graph.
# FEngine (64 bits) created at 0000021ADFD0C050 (threading is enabled)
# FEngine resolved backend: OpenGL
# c:\Users\21448\Desktop\repos\MMLfD-Tutorial\1.1. visualize_pouring_dataset.py:257: RuntimeWarning: invalid value encountered in divide
#   n = n/np.linalg.norm(n, axis=1, keepdims=True)
